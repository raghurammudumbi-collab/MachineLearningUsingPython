# %%
   import statistics
   d = [10, 20, 30, 40]
   r = statistics.mean(d)
   print(r)
# Out:
# 25

# %%
def findMean(a, n):
    sum = 0
    for i in range(0, n):
        sum += a[i]
    return float(sum / n)
# Driver program
a = [1, 3, 4, 2, 7, 5, 8, 6]
n = len(a)
print("Mean =", findMean(a, n))
# Out:
# Mean = 4.5
