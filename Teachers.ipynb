# %% [markdown]
# <a href="https://colab.research.google.com/github/raghurammudumbi-collab/MachineLearningUsingPython/blob/main/Teachers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# The 'r' before the string treats backslashes as a raw string literal
df = pd.read_csv("https://raw.githubusercontent.com/raghurammudumbi-collab/MachineLearningUsingPython/refs/heads/main/JSCD-TEACHERS.csv")

# View the column names
print(df.columns)
# Out:
# Index(['TID', 'TNAME', 'TAGE', 'TMRF', 'TSUB', 'TSAL'], dtype='object')

# %%
df
# Out:
#    TID TNAME  TAGE TMRF      TSUB   TSAL
# 0    1    T1    35    M     S1,S2  10000
# 1    2    T2    38    F        S3  20000
# 2    3    T3    40    F     S2,S3  25000
# 3    4    T4    50    F     S3,S4  18000
# 4    5    T5    57    M  S1,S2,S4  90000
# 5    6    T6    50    F  S2,S3,S4  20000
# 6    7    T7    45    M        S3  19000
# 7    8    T8    30    F     S1,S4  16000
